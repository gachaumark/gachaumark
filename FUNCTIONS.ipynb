# %% [markdown]
# <a href="https://colab.research.google.com/github/gachaumark/gachaumark/blob/main/FUNCTIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greetings():
    print("Hello World")
greetings()
# Out:
# Hello World

# %%
def myname(name):
  print(name)
myname("Isaac")
# Out:
# Isaac

# %%
x=20
y=40
sum=x+y
print(f"sum={sum}")
# Out:
# sum=60

# %%
def addnumbers(num1,num2):
  sum=num1+num2
  print(sum)
addnumbers(10,20)
# Out:
# 30

# %%
#Multiplication of Three numbers
def multiply(num1,num2,num3):
  product=num1*num2*num3
  print(product)
multiply(4,5,6)
# Out:
# 120

# %%
#SQUARE OF A NUMBER
def square(num):
  total=num*num
  print(total)
square(4)
# Out:
# 16

# %%
     #DETRMINE THE EVEN AND ODD NUMBERS
def rain(num):
  if num%2==0:
    print("even")
  else:
    print("odd")
num=int(input("Enter a number: "))
rain(num)
# Out:
# Enter a number: 64
# even

# %%
#RETURN STATEMENTS
def addTwoNumbers(num1,num2):
   return num1+num2
addition=addTwoNumbers(10,20)
print(addition)
# Out:
# 30

# %%
#RETURNS EVEN AND ODD
def prep(num):

 if num%2==0:
  return "even"
 else:
  print("odd")
num=int(input("Enter a number: "))
prep(num)
# Out:
# Enter a number: 34
# 'even'
