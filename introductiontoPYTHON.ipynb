# %% [markdown]
# <a href="https://colab.research.google.com/github/gachaumark/gachaumark/blob/main/introductiontoPYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# VARIABLE DECLARATION AND  ARITHMETIC OPERATIONS

# %%
num1=int(input("Enter first number"))
num2=int(input("Enter second number"))
sum=num1+num2
print(sum)
# Out:
# Enter first number34
# Enter second number45
# 79

# %%
#areaof trapezium,
a=int(input("Enter a"))
b=int(input("Enter b"))
height=(input("Enter Height"))
trapie= (a+b*height)/2
print(f"Area of Trapezium = {trapie}")
# Out:
# Enter a12
# Enter b14
# Enter Height16
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15008/2797199481.py in <cell line: 0>()
#       3 b=int(input("Enter b"))
#       4 height=(input("Enter Height"))
# ----> 5 trapie= (a+b*height)/2
#       6 print(f"Area of Trapezium = {trapie}")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#find area of a circle
radius=int(input("Enter the radius"))
pie=3.142
areaofcircle=(pie*radius*radius)
print(f"Arae of Circle={areaofcircle}")
# Out:
# Enter the radius14
# Arae of Circle=615.832

# %%
# find area of square
length=int(input("enter the length"))
square=(length*length)
print(f"Area of Sqaure= {square}")
# Out:
# enter the length24
# Area of Sqaure= 576

# %% [markdown]
# IDENTATIONS AND "if Statements"

# %%
print (2>5)
print ("2"==2)
print (3==3)
print (5>=5)
# Out:
# False
# False
# True
# True

# %%
ttet=50
if (ttet>100):
  print("yes")
print("Program is finished")
# Out:
# Program is finished

# %%
num=50
if (num<100):
  print("correct")
print("Your Done")
# Out:
# correct
# Your Done

# %%
age = 20
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
age=17
if (age>=18):
    print("Elligible")
else:
  print("Not Elligible for voting")
# Out:
# Not Elligible for voting

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
  print(f"{num} is an even number")
else:
  print(f"{num} is an odd number")
# Out:
# Enter a number: 45
# 45 is an odd number

# %%
year=int(input("Enter the year: "))
if (year%4==0):
  print(f"{year} is a leap year")
else:
  print(f"{year}is not a leap year")
# Out:
# Enter the year: 2007
# 2007is not a leap year

# %%
num=int (input("enter a Number"))
if (num>=0):
  print(f"{num} is a POSITIVE number")
else:
  print(f"{num} is a NEGATIVE NUMBER")
# Out:
# enter a Number89
# 89 is a POSITIVE number

# %%
light=input("Enter the traffic color")
if light=="Red":
  print(f"{light} means you STOP")
elif light=="Amber":
  print(f"{light} means be READY")
elif light=="Green":
  print(f"{light} means GO")
else:
  print("invalid input")
# Out:
# Enter the traffic colorwhite
# invalid input

# %%
#Traffic colors
colors=["red","amber","green"]
print (colors)
print (colors[1])
print (colors[-2])
# Out:
# ['red', 'amber', 'green']
# amber
# amber
