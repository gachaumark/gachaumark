# %% [markdown]
# <a href="https://colab.research.google.com/github/gachaumark/gachaumark/blob/main/SalaryCalc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CAT 1 .. PYTHON

# %%
PayRollnumber=int(input("Enter the PayRoll Number:"))
Name=input("Enter the Name:")
Gender=input("Enter your Gender")
JobGroup=(input("Enter the JobGroup:"))
Salary=int(input("Enter the Basic Salary:"))
print("PayRoll Number :",PayRollnumber)
print("Your Name is :",Name)
if Gender=="male":
  print("You are Male")
elif Gender=="female":
  print("You are Female")
else:
  print("You GAYY OR a ladyBOYY!!")
print("Your JobGroup :",JobGroup)
print("Total Monthly Salary :",Salary)
if JobGroup=='J':
  allowance=5000
elif JobGroup=="K":
  allowance=5500
elif JobGroup=="L":
  allowance=6000
elif JobGroup=="M":
  allowance=4000
else:
  print("Enter the correct JobGroup")
Grosspay=Salary+allowance
print("Grosspay:",Grosspay)
Taxes=12*Salary/100
print("Taxes:",Taxes)
Netpay=Grosspay-Taxes
print("Netpay:",Netpay)
# Out:
# Enter the PayRoll Number:324765
# Enter the Name:Mark
# Enter your Genderjik
# Enter the JobGroup:K
# Enter the Basic Salary:56000
# PayRoll Number : 324765
# Your Name is : Mark
# You GAYY OR a ladyBOYY!!
# Your JobGroup : K
# Total Monthly Salary : 56000
# Grosspay: 61500
# Taxes: 6720.0
# Netpay: 54780.0

# %%
PayRollnumber=int(input("Enter the PayRoll Number:"))
Name=input("Enter the Name:")
Gender=input("Enter your Gender")
JobGroup=(input("Enter the JobGroup:"))
Salary=int(input("Enter the Basic Salary:"))
print("PayRollNumber :",PayRollnumber)
print("Your Name is :",Name)
if Gender=="Male":
  print("You are Male")
elif Gender=="Female":
  print("You are Female")
else:
  print("You GAY OR  LadyBOYY!!")
print("You're JobGroup =",JobGroup)
print("Total Mothly Salary =",Salary)
if JobGroup=='J':
  allowance=5000
elif JobGroup=="K":
  allowance=5500
elif JobGroup=="L":
  allowance=6000
elif JobGroup=="M":
  allowance=4000
else:
  print("Enter the correct JobGroup")
Grosspay=Salary+allowance
print("Grosspay:",Grosspay)
Taxes=12*Salary/100
print("Taxes:",Taxes)
Netpay=Grosspay-Taxes
print("Netpay:",Netpay)
# Out:
#   File "/tmp/ipykernel_19331/3651089754.py", line 10
#     elif:
#         ^
# SyntaxError: invalid syntax
