# %% [markdown]
# <a href="https://colab.research.google.com/github/gachaumark/gachaumark/blob/main/colab_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#USER/PATIENTS INPUTS
print("WELCOME TO JESHI HOSPITAL".center(100))
Patient_Name=input("enter name")
print("Patient Name: ",Patient_Name)
Patient_Gender=input("enter gender")
print("Patient Gender: ",Patient_Gender)
Patient_Age=int(input("enter age"))
print("Patient Age: ",Patient_Age)
Place_of_residence=input("enter place of residence")
print("Place of residence: ",Place_of_residence)
#PATIENTS SYMPTOMS
print("Enter You're Symptoms")
Symptom1=input("enter symptom1")
Symptom2=input("enter symptom2")
#DISPLAY INFO
print("Patient Name: ",Patient_Name)
print("Patient Gender: ",Patient_Gender)
print("Patient Age: ",Patient_Age)
Place_of_residence=input("enter place of residence")
print("You're Symptoms;")
print("Symptom1 is:",Symptom1)
print("Symptom2 is:",Symptom2)
#Symptom Criteria
if Symptom1=="vomitting" and Symptom2=="diarrrhea":
   print("Typhoid")
elif Symptom1=="vommitting" and Symptom2=="fever":
   print("Malaria")
elif Symptom1=="chest_Pain" and Symptom2=="wheezing_Sound":
   print("Pneumonia")
elif Symptom1=="frequent_Urinations" and Symptom2=="sugar_flactuations":
   print("Diabetes")
else:
   print("Enter diagnostic symptoms")
# Out:
#                                      WELCOME TO JESHI HOSPITAL
